# %% [markdown]
# # 🧠 Customer Segmentation Using KMeans
#
# This project performs customer segmentation using the KMeans clustering algorithm on the popular Mall Customers dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df = pd.read_csv(r'C:\Users\PC\Desktop\Shreya\customer segmentation\Mall_Customers.csv')
print(df.head())
print(df.info())
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
inertia = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1, 11), inertia, marker='o', linestyle='--', color='b')
plt.title('Elbow Method for Optimal Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
df['Cluster'] = kmeans.fit_predict(X)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', 
                hue='Cluster', palette='Set1', data=df, s=100)
plt.title('Customer Segmentation Based on Income & Spending')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.grid(True)
plt.show()

# %%
df.to_csv('Mall_Customers_with_Clusters.csv', index=False)

# %% [markdown]
# ## ✅ Summary
#
# This project uses KMeans clustering to segment customers based on Annual Income and Spending Score.
# The Elbow Method identified 5 optimal clusters.
# These segments can help businesses target specific groups more effectively.
#
# **Tools Used**: Python, Pandas, Matplotlib, Seaborn, Scikit-learn
# **Author**: Shreya Mahadik
